# %%
import pandas as pd

df = pd.read_csv("healthcare_data.csv")

missing_values = df.isnull().sum()
print(missing_values)
# Out:
# Patient_ID           0
# Age                  0
# Gender               0
# BMI                  0
# Blood_Pressure       0
# Cholesterol_Level    0
# Diabetes             0
# Smoker               0
# Hospital_Visits      0
# Treatment_Cost       0
# dtype: int64

# %%
average_age = df['Age'].mean()
print("Average Age:", average_age)
# Out:
# Average Age: 53.202

# %%
gender_distribution = df['Gender'].value_counts()
print(gender_distribution)
# Out:
# Gender
# Male      258
# Female    242
# Name: count, dtype: int64

# %%
highest_cost_patient = df.loc[df['Treatment_Cost'].idxmax()]
print(highest_cost_patient)
# Out:
# Patient_ID              P0253
# Age                        47
# Gender                 Female
# BMI                      37.5
# Blood_Pressure             99
# Cholesterol_Level         242
# Diabetes                   No
# Smoker                    Yes
# Hospital_Visits            10
# Treatment_Cost       19991.33
# Name: 252, dtype: object

# %%
avg_bmi = df.groupby('Diabetes')['BMI'].mean()
print(avg_bmi)
# Out:
# Diabetes
# No     27.972932
# Yes    27.222222
# Name: BMI, dtype: float64
